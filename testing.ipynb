# %%
from uavsar_pytools.UavsarImg import UavsarImg
import pandas as pd

# %% [markdown]
# ## Using individual methods of the class

# %%
url1 = 'https://unzip.asf.alaska.edu/INTERFEROMETRY_GRD/UA/grmesa_27416_21011-010_21016-002_0021d_s01_L090_01_int_grd.zip/grmesa_27416_21011-010_21016-002_0021d_s01_L090HH_01.cor.grd'
main_dir = './data/imgs'
img1 = UavsarImg(url = url1, work_dir = main_dir)

# %%
img1.download(sub_dir= 'bin_imgs/')

# %%
img1.convert_to_tiff(overwrite = True)
# Out:
# INFO:uavsar_pytools.convert.tiff_conversion:Working with insar
# INFO:uavsar_pytools.convert.tiff_conversion:Finished converting image to WGS84 Geotiff.

# %%
img1.show()
# Out:
# /home/zacharykeskinen/Documents/uavsar_pytools/uavsar_pytools/UavsarImg.py:84: FutureWarning: elementwise != comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   if self.arr != None:

# %% [markdown]
# ## Using single url to tiff method

# %%
from uavsar_pytools.UavsarImg import UavsarImg
url2 = 'http://uavsar.asfdaac.alaska.edu/UA_Rosamd_35012_21067_013_211124_L090_CX_01/Rosamd_35012_21067_013_211124_L090_CX_01.inc'
main_dir = './data/imgs'

img2 = UavsarImg(url = url2, work_dir = main_dir)
img2.url_to_tiff()
# Out:
# INFO:uavsar_pytools.convert.tiff_conversion:Working with polsar
# INFO:uavsar_pytools.convert.tiff_conversion:Finished converting image to WGS84 Geotiff.

# %% [markdown]
# ## Testing many urls

# %%
from uavsar_pytools.UavsarImg import UavsarImg
import pandas as pd
main_dir = './data/imgs'
for url in pd.read_csv('./tests/data/urls').values.ravel():
    try:
        print(url)
        img3 = UavsarImg(url = url, work_dir = main_dir)
        img3.url_to_tiff()
        img3.show()
    except Exception as e: 
        print(e)
# Out:
# WARNING:uavsar_pytools.download.download:No ann url found. Unable to download ann file.
# WARNING:uavsar_pytools.download.download:No ann url found. Unable to download ann file.
# https://datapool.asf.alaska.edu/INC/UA/Rosamd_35012_21067_013_211124_L090_CX_01.inc
# https://datapool.asf.alaska.edu/SLOPE/UA/Rosamd_35012_21067_013_211124_L090_CX_01.slope
# https://unzip.asf.alaska.edu/COMPLEX/UA/Rosamd_35012_21067_013_211124_L090_CX_01_mlc.zip/Rosamd_35012_21067_013_211124_L090_CX_01.ann
# https://unzip.asf.alaska.edu/STOKES/UA/Rosamd_35012_21067_013_211124_L090_CX_01_stokes.zip/Rosamd_35012_21067_013_211124_L090_CX_01.dat
# WARNING:uavsar_pytools.download.download:No ann url found. Unable to download ann file.
# Can not handle dat products
# https://datapool.asf.alaska.edu/PAULI/UA/Rosamd_35012_21067_013_211124_L090_CX_01_pauli.tif
# https://unzip.asf.alaska.edu/COMPLEX/UA/Rosamd_35012_21067_013_211124_L090_CX_01_mlc.zip/Rosamd_35012_21067_013_211124_L090VVVV_CX_01.mlc
# ...

# %%
img3.arr.dtype
# Out:
# dtype([('real', '<f4')])

# %%
from uavsar_pytools.UavsarImg import UavsarImg
main_dir = './data/imgs'
import numpy as np
import matplotlib.pyplot as plt
url1 = 'http://uavsar.asfdaac.alaska.edu/UA_Rosamd_35012_21067_013_211124_L090_CX_01/Rosamd_35012_21067_013_211124_L090HHHH_CX_01.grd'
img1 = UavsarImg(url = url1, work_dir = main_dir)
img1.url_to_tiff()
# Out:
# INFO:uavsar_pytools.convert.tiff_conversion:Working with polsar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_241243/1248807584.py in <module>
#       5 url1 = 'http://uavsar.asfdaac.alaska.edu/UA_Rosamd_35012_21067_013_211124_L090_CX_01/Rosamd_35012_21067_013_211124_L090HHHH_CX_01.grd'
#       6 img1 = UavsarImg(url = url1, work_dir = main_dir)
# ----> 7 img1.url_to_tiff()
#
# ~/Documents/uavsar_pytools/uavsar_pytools/UavsarImg.py in url_to_tiff(self, down_dir)
#      96         self.download(sub_dir = down_dir)
#      97         if self.ann_fp:
# ---> 98             self.convert_to_tiff()
#
# ~/Documents/uavsar_pytools/uavsar_pytools/UavsarImg.py in convert_to_tiff(self, binary_fp, sub_dir, ann_fp, overwrite)
#      73             ann_fp = self.ann_fp
#      74
# ...

# %%
len(img1.arr.dtype)
# Out:
# 1

# %%
img1.show()
# Out:
# /home/zacharykeskinen/Documents/uavsar_pytools/uavsar_pytools/UavsarImg.py:81: FutureWarning: elementwise != comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   if self.arr != None:

# %%
m = (img1.arr['real']**2+img1.arr['imaginary']**2)**.5

# %%
plt.imshow(m,vmax = 0.02, vmin = -0.02)
plt.colorbar()

# %%
img1.arr['real']
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %%
img1.arr.real
# Out:
# array([[(nan, nan), (nan, nan), (nan, nan), ..., (nan, nan), (nan, nan),
#         (nan, nan)],
#        [(nan, nan), (nan, nan), (nan, nan), ..., (nan, nan), (nan, nan),
#         (nan, nan)],
#        [(nan, nan), (nan, nan), (nan, nan), ..., (nan, nan), (nan, nan),
#         (nan, nan)],
#        ...,
#        [(nan, nan), (nan, nan), (nan, nan), ..., (nan, nan), (nan, nan),
#         (nan, nan)],
#        [(nan, nan), (nan, nan), (nan, nan), ..., (nan, nan), (nan, nan),
#         (nan, nan)],
#        [(nan, nan), (nan, nan), (nan, nan), ..., (nan, nan), (nan, nan),
#         (nan, nan)]], dtype=[('real', '<f4'), ('imaginary', '<f4')])

# %%
plt.imshow(img1.arr.real, vmin = -0.2, vmax = 0.2)
plt.colorbar()

# %%
img1.show()
# Out:
# /home/zacharykeskinen/Documents/uavsar_pytools/uavsar_pytools/UavsarImg.py:81: FutureWarning: elementwise != comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   if self.arr != None:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_80425/3228036520.py in <module>
# ----> 1 img1.show()
#
# ~/Documents/uavsar_pytools/uavsar_pytools/UavsarImg.py in show(self)
#      83                 d = self.arr.astype(float)
#      84             else:
# ---> 85                 d = np.sqrt(self.arr.real**2 + self.arr.imag**2)
#      86             std_low = np.nanmean(d) - 2* np.nanstd(d)
#      87             std_high = np.nanmean(d) + 2* np.nanstd(d)
#
# ...
